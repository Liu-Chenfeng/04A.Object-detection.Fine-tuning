# %% [markdown]
# ## 1.Prepare

# %% [markdown]
# 1.1 Check watermark.yaml
# 1.2 Check path
# 1.3 Download YOLOv8

# %% [markdown]
# ## 2. Train

# %% [markdown]
# 2.1 Use CLI to train
# ```bash
# yolo train model="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/yolov8m.pt" \
#     data="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/WatermarkDataset/watermark.yaml" \
#     epochs=3 batch=32 imgsz=640 device=0 \
#     project="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning" name="YOLOv8_Fine-Tuning"
# ```

# %% [markdown]
# ```bash
# Microsoft Windows [版本 10.0.22631.4317]
# (c) Microsoft Corporation。保留所有权利。
#
# C:\Users\lcf14>yolo train model="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/yolov8m.pt" data="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/WatermarkDataset/watermark.yaml" epochs=3 batch=32 imgsz=640 device=0 project="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning" name="YOLOv8_Fine-Tuning"
# New https://pypi.org/project/ultralytics/8.3.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.52 🚀 Python-3.11.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# engine\trainer: task=detect, mode=train, model=C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/yolov8m.pt, data=C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/WatermarkDataset/watermark.yaml, epochs=3, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=8, project=C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning, name=YOLOv8_Fine-Tuning, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 295 layers, 25857478 parameters, 25857462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\labels\train... 480
# train: WARNING ⚠️ C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\images\train\n04141327_9115.jpg: ignoring corrupt image/label: negative label values [      -0.11]
# train: New cache created: C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\labels\train.cache
# val: Scanning C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\labels\val... 12000 i
# val: New cache created: C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\labels\val.cache
# Plotting labels to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/3      13.4G      1.447      1.521       1.26        154        640: 100%|██████████| 1500/1500 [7:49:25<00:0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 188/188 [20:24
#                    all      12000      31915      0.809      0.736      0.788      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/3      13.4G      1.187      1.076      1.133        129        640: 100%|██████████| 1500/1500 [6:24:05<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 188/188 [18:49
#                    all      12000      31915      0.894      0.803      0.867      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/3      13.3G      1.038     0.8731      1.064         99        640: 100%|██████████| 1500/1500 [7:08:43<00:00,
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 188/188 [23:57
#                    all      12000      31915      0.921      0.854      0.915      0.674
#
# 3 epochs completed in 22.429 hours.
# Optimizer stripped from C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning\weights\last.pt, 52.0MB
# Optimizer stripped from C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning\weights\best.pt, 52.0MB
#
# Validating C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning\weights\best.pt...
# Ultralytics YOLOv8.2.52 🚀 Python-3.11.5 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# C:\Users\lcf14\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ..\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 188/188 [15:41
#                    all      12000      31915       0.92      0.855      0.915      0.674
#              watermark      11964      31915       0.92      0.855      0.915      0.674
# Speed: 0.4ms preprocess, 74.3ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning
# 💡 Learn more at https://docs.ultralytics.com/modes/train
#
# C:\Users\lcf14>yolo train model="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/yolov8m.pt" data="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning/WatermarkDataset/watermark.yaml" epochs=3 batch=32 imgsz=640 device=0 project="C:/Users/lcf14/Desktop/homework/Machine_Learning_appli/Fine_Tuning" name="YOLOv8_Fine-Tuning"^A

# %% [markdown]
# 2.2 Check the results of training
# ```
# 损失值：
# box_loss=1.038: 边界框的回归损失。
# cls_loss=0.8731: 分类损失。
# dfl_loss=1.064: 分布式 Focal 损失，用于边界框预测的更精确定位。
# 性能指标：
# Precision (P) = 0.921: 精确率，检测到的水印中，有 92.1% 是正确的。
# Recall (R) = 0.854: 召回率，所有水印中，模型成功检测出 85.4%。
# mAP50 = 0.915: 平均精度 (IoU=50%) 为 91.5%。
# mAP50-95 = 0.674: 平均精度 (IoU=50%~95%) 为 67.4%。
#
# Loss value:
# box_loss=1.038: regression loss for bounding box.
# cls_loss=0.8731: Classification loss.
# dfl_loss=1.064: Distributed Focal loss for more precise localisation of bounding box predictions.
# Performance Metrics:
# Precision (P) = 0.921: Precision rate, 92.1% of detected watermarks are correct.
# Recall (R) = 0.854: Recall rate, the model successfully detected 85.4% of all watermarks.
# mAP50 = 0.915: Average accuracy (IoU=50%) is 91.5%.
# mAP50-95 = 0.674: average precision (IoU=50%~95%) is 67.4%.

# %% [markdown]
# ## Demonstrate

# %%
import os
import random
from ultralytics import YOLO
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# %%
# 配置模型路径和图片文件夹路径
model_path = r"C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\YOLOv8_Fine-Tuning\weights\best.pt"
image_folder = r"C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100"
save_dir = r"C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\results"

# 加载训练好的 YOLO 模型
model = YOLO(model_path)

# 获取文件夹中的所有图片路径
image_files = [os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith(('.jpg'))]

# %%
# 随机选择 5 张图片
random_images = random.sample(image_files, 5)

# 对每张图片进行检测并保存结果
results = []
for img_path in random_images:
    result = model.predict(source=img_path, save=True, project=save_dir)  # 自动保存检测结果

    # 获取保存结果的文件夹路径，假设 "predictX" 文件夹名为结果文件夹
    result_folder = os.path.join(save_dir, f"predict{len(os.listdir(save_dir))}")
    
    # 获取结果图像的路径，使用原始图像的文件名
    detected_image_path = os.path.join(result_folder, os.path.basename(img_path))

    results.append((img_path, detected_image_path))
# Out:
# image 1/1 C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\n01828970_4940v2.jpg: 480x640 21 watermarks, 151.8ms
# Speed: 4.9ms preprocess, 151.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\results\predict27
#
# image 1/1 C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\n01806567_2907v2.jpg: 448x640 1 watermark, 120.4ms
# Speed: 5.3ms preprocess, 120.4ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\results\predict28
#
# image 1/1 C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\WatermarkDataset\sample_images_100\n02319095_5005.jpg: 480x640 18 watermarks, 90.6ms
# ...

# %%
# 显示检测结果
for img_path, detected_image_path in results:
    # 加载原图
    original_image = Image.open(img_path)

    # 加载检测后的图片
    detected_image = Image.open(detected_image_path)

    # 显示图片
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Original Image")
    plt.imshow(original_image)
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.title("Detected Image")
    plt.imshow(detected_image)
    plt.axis("off")

    plt.show()

# %%
# 配置图片文件路径
image_path_single = r"C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\MarkCheck\11.jpg"  # 独立的图片路径
save_dir_single = r"C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\MarkCheck\restult"  # 独立的结果保存路径

# 执行检测
result_single = model.predict(source=image_path_single, save=True, project=save_dir_single)  # 不保存文件，直接返回检测结果

# 获取保存结果的文件夹路径，假设 "predictX" 文件夹名为结果文件夹
result_folder_single = os.path.join(save_dir_single, f"predict{len(os.listdir(save_dir_single))}")

# 获取结果图像的路径，使用原始图像的文件名
detected_image_path_single = os.path.join(result_folder_single, os.path.basename(image_path_single))

# 加载原图
original_image_single = Image.open(image_path_single)

# 加载检测后的图片
detected_image_single = Image.open(detected_image_path_single)

# 显示图片
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(original_image_single)
plt.axis("off")

plt.subplot(1, 2, 2)
plt.title("Detected Image")
plt.imshow(detected_image_single)
plt.axis("off")

plt.show()
# Out:
# image 1/1 C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\MarkCheck\11.jpg: 416x640 2 watermarks, 132.0ms
# Speed: 5.0ms preprocess, 132.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to C:\Users\lcf14\Desktop\homework\Machine_Learning_appli\Fine_Tuning\MarkCheck\restult\predict15
